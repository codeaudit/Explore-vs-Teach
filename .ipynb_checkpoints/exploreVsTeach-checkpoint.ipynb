# %%
# %matplotlib inline

from utils_pattern import genMasterPermSet2x2
from utils_pattern import hypo2perm

from e_vs_t import model

from vis_utils import vis_config
from vis_utils import vis_hypoProbeMatrix # v1
# from vis_utils import vis_hypoProbeObsMatrix # v2 trial

master_set = genMasterPermSet2x2()
hypo = [[0,4,2],[1,2]]
perm = hypo2perm(hypo, master_set)
person = model(perm)
vis_config(person)

Xd = []
Yd = []
vis_hypoProbeMatrix(person, Xd, Yd)
# Out:
# iteration 0
# input M summed over y: [[ 1.4         1.25        0.66666667  0.97142857]
#  [ 0.6         0.75        1.33333333  1.02857143]]
# predictive marginalization of y: [[ 0.13992227  0.17490283  0.15546918  0.11993337]
#  [ 0.16164208  0.2020526   0.17960231  0.13855035]]
# max thresh: [[ 0.          0.17490283  0.          0.        ]
#  [ 0.          0.2020526   0.          0.        ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.4         1.        ]
#   [ 1.          0.25      ]
#   [ 0.          0.66666667]
#   [ 0.57142857  0.4       ]]
#
#  [[ 0.6         0.        ]
#   [ 0.          0.75      ]
#   [ 1.          0.33333333]
#   [ 0.42857143  0.6       ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Not converging yet.
# /Users/CoDaS/Dropbox/ShaftoLab/e-vs-t/Explore-vs-Teach/utils.py:82: UserWarning: All entries should >=0 with at least one >0
#   warnings.warn('All entries should >=0 with at least one >0')
# iteration 1
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 2
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 3
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 4
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 5
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 6
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 7
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 8
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 9
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 10
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 11
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 12
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 13
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 14
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 15
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 16
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 17
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 18
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!
# iteration 19
# input M summed over y: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# predictive marginalization of y: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# max thresh: [[ 0.   0.6  0.   0. ]
#  [ 0.   1.   0.   0. ]]
# normalize probe after max: [[ 0.  1.  0.  0.]
#  [ 0.  1.  0.  0.]]
# update M: [[ 0.    1.25  0.    0.  ]
#  [ 0.    0.75  0.    0.  ]]
# input M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# output M: [[[ 0.    0.  ]
#   [ 1.    0.25]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]
#
#  [[ 0.    0.  ]
#   [ 0.    0.75]
#   [ 0.    0.  ]
#   [ 0.    0.  ]]]
# Converged!

# %%
# %matplotlib inline
from utils_pattern import genMasterPermSet2x2
from utils_pattern import hypo2perm
from e_vs_t import model
from vis_utils import vis_config

from simulate import explore
from simulate import teach

master_set = genMasterPermSet2x2()
hypo = [[0,1,3],[4,5,3]]
perm = hypo2perm(hypo, master_set)
person = model(perm)
vis_config(person)

# person.change_mode("softmax", 20, "one-step")
ihypo = 0
ipatt = 2
pattern = person.perm[ihypo][ipatt]
max_step = 4
teach(person, ihypo, pattern, max_step, True)
# Out:
# /Users/CoDaS/Dropbox/ShaftoLab/e-vs-t/Explore-vs-Teach/utils.py:82: UserWarning: All entries should >=0 with at least one >0
#   warnings.warn('All entries should >=0 with at least one >0')
# step 0
# P_T(x|h) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.083333333333333329], [0.083333333333333329, 0.083333333333333329, 0.083333333333333329]]
# Before update P(h|D) = [ 0.5  0.5]
# After update P(h|D) = [ 0.25  0.75]
# score = [  4.99998000e-01   1.99998400e-06   1.99998400e-06   4.99998000e-01]
# data = [0]; [1.0]
# step 1
# P_T(x|h) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.041666666666666664], [0.0, 0.0, 0.041666666666666664]]
# Before update P(h|D) = [ 0.25  0.75]
# After update P(h|D) = [ 0.5  0.5]
# score = [  9.99993000e-07   1.99998600e-06   1.99998600e-06   9.99995000e-01]
# data = [0, 3]; [1.0, 1.0]
# step 2
# P_T(x|h) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.020833333333333332], [0.0, 0.0, 0.020833333333333332]]
# Before update P(h|D) = [ 0.5  0.5]
# After update P(h|D) = [ 0.5  0.5]
# score = [  9.99994000e-07   4.99999000e-01   4.99999000e-01   9.99994000e-07]
# data = [0, 3, 1]; [1.0, 1.0, 0.0]
# step 3
# P_T(x|h) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.010416666666666666], [0.0, 0.0, 0.010416666666666666]]
# Before update P(h|D) = [ 0.5  0.5]
# After update P(h|D) = [ 0.5  0.5]
# score = [  9.99995000e-07   9.99995000e-07   9.99997000e-01   9.99995000e-07]
# data = [0, 3, 1, 2]; [1.0, 1.0, 0.0, 0.0]
# [0.5, 0.25, 0.5, 0.5]

# %%
# %matplotlib inline
from utils_pattern import genMasterPermSet2x2
from utils_pattern import hypo2perm
from e_vs_t import model
from vis_utils import vis_config

from simulate import explore
from simulate import teach

master_set = genMasterPermSet2x2()
hypo = [[0,1,3],[4,5,3]]
perm = hypo2perm(hypo, master_set)
person = model(perm)
vis_config(person)

# person.change_mode("softmax", 20, "one-step")
ihypo = 1
ipatt = 2
pattern = person.perm[ihypo][ipatt]
max_step = 4
explore(person, ihypo, pattern, max_step, True)
# Out:
# step 0
# P(h|D) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.16666666666666666], [0.16666666666666666, 0.16666666666666666, 0.16666666666666666]]
# score = [ 0.31825708  0.          0.          0.31825708]
# data = [0]; [1.0]
# step 1
# P(h|D) = [ 0.25  0.75]
# P(h,f|D) = [[0.0, 0.0, 0.16666666666666666], [0.0, 0.0, 0.16666666666666666]]
# score = [ 0.          0.14058379  0.14058379  0.28116757]
# data = [0, 3]; [1.0, 1.0]
# /Users/CoDaS/Dropbox/ShaftoLab/e-vs-t/Explore-vs-Teach/utils.py:74: UserWarning: All entries should >=0 with at least one >0
#   warnings.warn('All entries should >=0 with at least one >0')
# /Users/CoDaS/anaconda3/envs/py35/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py:2493: RuntimeWarning: invalid value encountered in true_divide
#   pk = 1.0*pk / sum(pk, axis=0)
# step 2
# P(h|D) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.16666666666666666], [0.0, 0.0, 0.16666666666666666]]
# score = [ 0.  0.  0.  0.]
# data = [0, 3, 2]; [1.0, 1.0, 0.0]
# step 3
# P(h|D) = [ 0.5  0.5]
# P(h,f|D) = [[0.0, 0.0, 0.16666666666666666], [0.0, 0.0, 0.16666666666666666]]
# score = [ 0.  0.  0.  0.]
# data = [0, 3, 2, 1]; [1.0, 1.0, 0.0, 0.0]
# [0.5, 0.75, 0.5, 0.5]

# %%
from utils_pattern import set_lili_diff

lili1 = [[0,1,2,3,4,5],[5]]
lili2 = [[0,1,2,3],[3,4,5]]

lili1 = [[0, 1, 2, 3, 4], [0, 5]]
lili2 = [[0, 1, 2, 3, 5], [3, 4]]

a = set_lili_diff(lili1, lili2)
print(a)
len(a)

# %%
from scipy.stats import entropy
x = [0.5, 0.5, 0., 0.]
entropy(x)
# Out:
# 0.69314718055994529

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
a = np.array([1,2,3,4])
b = np.reshape(a,(2,2))
b
plt.imshow(b, interpolation="nearest", cmap="gray")
plt.show()

# %%
from utils_pattern import set_lili_diff
hypo_i = [[0,1,2,3,4,5],[2]]
hypo_j = [[0,1,2,4,5],[2,3,5]]
print(len(set_lili_diff(hypo_i, hypo_j)))
hypo_i = [[0,1,2],[3]]
hypo_j = [[0,1,3],[2]]
print(len(set_lili_diff(hypo_i, hypo_j)))
# Out:
# 2
# 2
